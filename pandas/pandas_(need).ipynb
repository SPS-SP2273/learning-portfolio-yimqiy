# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Pandas (Need)</span></div>

# %% [markdown]
# ## 1 What is a dataframe

# %% [markdown]
# ### 1.1 Reading data from csv or excel files.

# %%
import pandas as pd
import numpy as np
df_class = pd.read_excel("dummy-class-1-of-2.xlsx", skiprows = 1)
df_class
# Out:
#     Unnamed: 0                Name Student No Major Gender Test 2 (20%)  \
# 0            0      Braiden Henson  A3028967J   PHY      M      '18.96'
# 1            1        Gustavo Vang  A1282849W   CHM      F      '17.44'
# 2            2     Ronin Christian  A5408925A   PHY      M      '15.56'
# 3            3       Owen Anderson  A6973859L    LS      F      '16.36'
# 4            4          Kyla Young  A5410124H   PHY      M          NaN
# 5            5        Wyatt Oliver  A9568373Q   PHY      M     '14.088'
# 6            6       Essence Bauer  A6824244G    LS      M      '16.72'
# 7            7   Maryjane Sandoval  A9194090U    LS      F       '16.4'
# 8            8       Carl Trujillo  A4828364M    LS     NB      '13.68'
# 9            9         Halle Fritz  A4607700C    LS      F       '9.04'
# 10          10       Marie Hoffman  A7067766E    LS      F      '16.88'
# 11          11    Lilianna Kaufman  A5569996J    LS      M       '17.0'
# ...

# %% [markdown]
# ### 1.2 Characteristics to notice

# %% [markdown]
# 1. The first is the presence of an index (shown in bold) for each row (0 1 2 3...). This simple fact simplifies doing things with your data. I will show you some examples later.
# 2. The second is that a column (called a Pandas Series) can only have a single type of data. So, for example, you can have numbers or text; but not both.
# 3. The third is the presence of NaN (‘Not-a-Number’) when data is missing. Missing data is a common bane of real data; Pandas offer powerful ways to transparently deal with such missing numbers. I will show more later in this chapter.ere

# %% [markdown]
# ## 2 Quick Peeks

# %% [markdown]
# ### 2.1 Head and Tail

# %%
df_class.head(3)
# Out:
#    Unnamed: 0             Name Student No Major Gender Test 2 (20%)  \
# 0           0   Braiden Henson  A3028967J   PHY      M      '18.96'
# 1           1     Gustavo Vang  A1282849W   CHM      F      '17.44'
# 2           2  Ronin Christian  A5408925A   PHY      M      '15.56'
#
#    Test 1 (30%)
# 0        20.205
# 1        13.470
# 2        18.366

# %%
df_class.tail(3)
# Out:
#     Unnamed: 0          Name Student No Major Gender Test 2 (20%)  \
# 32          32   Katie Ayers  A6867791C  CBIO      F      '10.28'
# 33          33  Tucker Sloan  A4080490P    LS      M      '15.04'
# 34          34  Carter Crane  A7667457P    LS      M     '13.816'
#
#     Test 1 (30%)
# 32        16.530
# 33        17.754
# 34        20.817

# %% [markdown]
# ### 2.2 Size and Shape

# %%
print(df_class.shape)
print(len(df_class))
df_class.columns
# Out:
# (35, 7)
# 35
# Index(['Unnamed: 0', 'Name', 'Student No', 'Major', 'Gender', 'Test 2 (20%)',
#        'Test 1 (30%)'],
#       dtype='object')

# %% [markdown]
# ### 2.3 Summaries (I)

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    35 non-null     int64
#  1   Name          35 non-null     object
#  2   Student No    35 non-null     object
#  3   Major         35 non-null     object
#  4   Gender        35 non-null     object
#  5   Test 2 (20%)  32 non-null     object
#  6   Test 1 (30%)  33 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.0+ KB

# %%
df_class.describe(include="all")
#first 3 columns aren't useful
# Out:
#         Unnamed: 0            Name Student No Major Gender Test 2 (20%)  \
# count    35.000000              35         35    35     35           32
# unique         NaN              35         35     4      3           27
# top            NaN  Braiden Henson  A3028967J    LS      M      '14.36'
# freq           NaN               1          1    14     16            3
# mean     17.000000             NaN        NaN   NaN    NaN          NaN
# std      10.246951             NaN        NaN   NaN    NaN          NaN
# min       0.000000             NaN        NaN   NaN    NaN          NaN
# 25%       8.500000             NaN        NaN   NaN    NaN          NaN
# 50%      17.000000             NaN        NaN   NaN    NaN          NaN
# 75%      25.500000             NaN        NaN   NaN    NaN          NaN
# max      34.000000             NaN        NaN   NaN    NaN          NaN
#
#         Test 1 (30%)
# count      33.000000
# unique           NaN
# top              NaN
# ...

# %% [markdown]
# ### 2.4 Summaries (II)

# %%
print(df_class['Test 1 (30%)'].mean())
print(df_class[['Test 1 (30%)', 'Test 2 (20%)']].mean())
print(df_class['Major'].values)
print(df_class['Major'].unique())
print(df_class['Major'].value_counts())
print(df_class['Major'].value_counts().to_dict())
print(df_class['Major'].value_counts().to_list())
print(df_class['Major'].value_counts().index.to_list())
# Out:
# 18.534454545454548
# Test 1 (30%)    18.534455
# dtype: float64
# ['PHY' 'CHM' 'PHY' 'LS' 'PHY' 'PHY' 'LS' 'LS' 'LS' 'LS' 'LS' 'LS' 'PHY'
#  'LS' 'CHM' 'PHY' 'CHM' 'PHY' 'CHM' 'CHM' 'PHY' 'CHM' 'LS' 'LS' 'LS' 'PHY'
#  'PHY' 'PHY' 'CHM' 'LS' 'CHM' 'PHY' 'CBIO' 'LS' 'LS']
# ['PHY' 'CHM' 'LS' 'CBIO']
# LS      14
# PHY     12
# CHM      8
# CBIO     1
# Name: Major, dtype: int64
# {'LS': 14, 'PHY': 12, 'CHM': 8, 'CBIO': 1}
# [14, 12, 8, 1]
# ['LS', 'PHY', 'CHM', 'CBIO']
# C:\Users\yimqi\AppData\Local\Temp/ipykernel_20120/2600065898.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df_class[['Test 1 (30%)', 'Test 2 (20%)']].mean())

# %% [markdown]
# ## 3 Housekeeping

# %% [markdown]
# ### 3.1 Dropping unnecessary columns
#
# Must equate the drop operation to the original df

# %%
df_class = df_class.drop(columns=['Unnamed: 0'])
# default is rows (index), so much specify columns
df_class.head()
# alt: df_class.drop(columns=['Unnamed: 0'], inplace=True)
# Out:
#               Name Student No Major Gender Test 2 (20%)  Test 1 (30%)
# 0   Braiden Henson  A3028967J   PHY      M      '18.96'        20.205
# 1     Gustavo Vang  A1282849W   CHM      F      '17.44'        13.470
# 2  Ronin Christian  A5408925A   PHY      M      '15.56'        18.366
# 3    Owen Anderson  A6973859L    LS      F      '16.36'        18.366
# 4       Kyla Young  A5410124H   PHY      M          NaN        15.306

# %% [markdown]
# ### 3.2 Reorganising columns

# %%
columns_to_keep = ['Student No', 'Name', 'Major', 'Gender',
                   'Test 1 (30%)', 'Test 2 (20%)']

df_class = df_class[columns_to_keep]

# %% [markdown]
# ### 3.3 Renaming columns

# %%
new_column_info = {'Student No': 'MATRIC_NO',
                   'Test 1 (30%)': 'Test 1',
                   'Test 2 (20%)': 'Test 2'}

df_class.rename(columns=new_column_info, inplace=True)
df_class.head()
# Out:
#    MATRIC_NO             Name Major Gender  Test 1   Test 2
# 0  A3028967J   Braiden Henson   PHY      M  20.205  '18.96'
# 1  A1282849W     Gustavo Vang   CHM      F  13.470  '17.44'
# 2  A5408925A  Ronin Christian   PHY      M  18.366  '15.56'
# 3  A6973859L    Owen Anderson    LS      F  18.366  '16.36'
# 4  A5410124H       Kyla Young   PHY      M  15.306      NaN

# %% [markdown]
# ### 3.4 Setting the index

# %%
print(df_class.index)
df_class.set_index('MATRIC_NO', drop=False, inplace=True)
print(df_class.index)
df_class.head()
# Out:
# RangeIndex(start=0, stop=35, step=1)
# Index(['A3028967J', 'A1282849W', 'A5408925A', 'A6973859L', 'A5410124H',
#        'A9568373Q', 'A6824244G', 'A9194090U', 'A4828364M', 'A4607700C',
#        'A7067766E', 'A5569996J', 'A3202548I', 'A6131593U', 'A7653832E',
#        'A9462811I', 'A1218599T', 'A7210476B', 'A1512479K', 'A7986368Y',
#        'A2727061A', 'A2999472W', 'A7116486E', 'A6931452S', 'A9649096H',
#        'A1643380L', 'A6787293E', 'A5975988J', 'A3699958T', 'A1956366U',
#        'A1468689D', 'A3217320C', 'A6867791C', 'A4080490P', 'A7667457P'],
#       dtype='object', name='MATRIC_NO')
#            MATRIC_NO             Name Major Gender  Test 1   Test 2
# MATRIC_NO
# A3028967J  A3028967J   Braiden Henson   PHY      M  20.205  '18.96'
# A1282849W  A1282849W     Gustavo Vang   CHM      F  13.470  '17.44'
# A5408925A  A5408925A  Ronin Christian   PHY      M  18.366  '15.56'
# A6973859L  A6973859L    Owen Anderson    LS      F  18.366  '16.36'
# ...

# %% [markdown]
# ### 3.5 Applying changes

# %%
print(df_class['Major'].unique())
print(df_class['Gender'].unique())
replace_info = {
    'PHY': 'Physics',
    'CHM': 'Chemistry',
    'LS': 'Life Sciences',
    'CBIO': 'Comp. Biology',
    'F': 'Female',
    'M': 'Male',
    'NB': 'Non-binary'
}

df_class.replace(to_replace=replace_info, inplace=True)

def clean(text):
    try:
        return text.replace("'", "")
    except AttributeError:
        # This will handle the NaN of the missing data
        return text

df_class['Test 2'] = df_class['Test 2'].apply(clean)
df_class.head()
# Out:
# ['Physics' 'Chemistry' 'Life Sciences' 'Comp. Biology']
# ['Male' 'Female' 'Non-binary']
#            MATRIC_NO             Name          Major  Gender  Test 1 Test 2
# MATRIC_NO
# A3028967J  A3028967J   Braiden Henson        Physics    Male  20.205  18.96
# A1282849W  A1282849W     Gustavo Vang      Chemistry  Female  13.470  17.44
# A5408925A  A5408925A  Ronin Christian        Physics    Male  18.366  15.56
# A6973859L  A6973859L    Owen Anderson  Life Sciences  Female  18.366  16.36
# A5410124H  A5410124H       Kyla Young        Physics    Male  15.306    NaN

# %% [markdown]
# ### 3.6 Changing Column Type

# %%
df_class.info()
# Test 2 is still not a number?
new_type_info = {'Major': 'category',
                 'Gender': 'category',
                 'Test 2': 'float'}

# atype does NOT have an inplace option
df_class = df_class.astype(new_type_info)  
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, A3028967J to A7667457P
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MATRIC_NO  35 non-null     object
#  1   Name       35 non-null     object
#  2   Major      35 non-null     object
#  3   Gender     35 non-null     object
#  4   Test 1     33 non-null     float64
#  5   Test 2     32 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 1.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, A3028967J to A7667457P
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MATRIC_NO  35 non-null     object
#  1   Name       35 non-null     object
#  2   Major      35 non-null     category
#  3   Gender     35 non-null     category
#  4   Test 1     33 non-null     float64
#  5   Test 2     32 non-null     float64
# dtypes: category(2), float64(2), object(2)
# ...

# %% [markdown]
# ### 3.7 Adding a new column

# %%
df_class["Total"] = df_class["Test 1"] + df_class["Test 2"]
df_class.head()
# Out:
#            MATRIC_NO             Name          Major  Gender  Test 1  Test 2  \
# MATRIC_NO
# A3028967J  A3028967J   Braiden Henson        Physics    Male  20.205   18.96
# A1282849W  A1282849W     Gustavo Vang      Chemistry  Female  13.470   17.44
# A5408925A  A5408925A  Ronin Christian        Physics    Male  18.366   15.56
# A6973859L  A6973859L    Owen Anderson  Life Sciences  Female  18.366   16.36
# A5410124H  A5410124H       Kyla Young        Physics    Male  15.306     NaN
#
#             Total
# MATRIC_NO
# A3028967J  39.165
# A1282849W  30.910
# A5408925A  33.926
# A6973859L  34.726
# A5410124H     NaN

# %% [markdown]
# ### 3.8 Saving to file

# %%
df_class.to_excel('finalised_scores.xlsx', index=False)
# don't write the index column

# %% [markdown]
# ### 3.9 The recipe so far

# %% [markdown]
# ## 4 Asking questions

# %% [markdown]
# ### 4.1 Locating data

# %%
df_class.iloc[10:13, 2:4]
# Out:
#                    Major  Gender
# MATRIC_NO
# A7067766E  Life Sciences  Female
# A5569996J  Life Sciences    Male
# A3202548I        Physics    Male

# %% [markdown]
# ### 4.2 Asking questions with masks

# %%
df_class.loc[['A7067766E', 'A5569996J', 'A3202548I'], ['Major', 'Gender']]
# Out:
#                    Major  Gender
# MATRIC_NO
# A7067766E  Life Sciences  Female
# A5569996J  Life Sciences    Male
# A3202548I        Physics    Male

# %%
df_class.loc[~(df_class['Major'] == 'Life Sciences') & (df_class["Test 1"] < 15)]
# Out:
#            MATRIC_NO              Name      Major  Gender  Test 1  Test 2  \
# MATRIC_NO
# A1282849W  A1282849W      Gustavo Vang  Chemistry  Female  13.470  17.440
# A9568373Q  A9568373Q      Wyatt Oliver    Physics    Male  12.246  14.088
# A3202548I  A3202548I       Jaxon Chung    Physics    Male  14.082  16.680
# A2727061A  A2727061A      Malik Becker    Physics    Male  12.858     NaN
# A1643380L  A1643380L  Carolina Mcmahon    Physics    Male  12.858  18.080
#
#             Total
# MATRIC_NO
# A1282849W  30.910
# A9568373Q  26.334
# A3202548I  30.762
# A2727061A     NaN
# A1643380L  30.938

# %% [markdown]
# ### 4.3 The magic of groupby()

# %%
df_class.groupby(by=['Major']).mean()
# Out:
#                 Test 1     Test 2      Total
# Major
# Chemistry      18.7755  16.610286  35.534167
# Comp. Biology  16.5300  10.280000  26.810000
# Life Sciences  19.2420  14.690286  33.932286
# Physics        17.7555  16.076800  34.567000

# %%
df_class.groupby(by=['Major', 'Gender'], as_index=False).mean()
# Out:
#             Major      Gender     Test 1     Test 2      Total
# 0       Chemistry      Female  17.602500  16.364800  34.128500
# 1       Chemistry        Male  21.121500  17.224000  38.345500
# 2       Chemistry  Non-binary        NaN        NaN        NaN
# 3   Comp. Biology      Female  16.530000  10.280000  26.810000
# 4   Comp. Biology        Male        NaN        NaN        NaN
# 5   Comp. Biology  Non-binary        NaN        NaN        NaN
# 6   Life Sciences      Female  19.285875  14.801000  34.086875
# 7   Life Sciences        Male  20.357250  15.644000  36.001250
# 8   Life Sciences  Non-binary  16.836000  12.340000  29.176000
# 9         Physics      Female  20.817000  14.680000  35.497000
# 10        Physics        Male  16.871000  16.498286  34.166143
# 11        Physics  Non-binary  20.205000  15.300000  35.505000

# %%
pd.Series.to_frame(df_class.groupby(by=["Major", "Gender"])["Test 1"].mean())

# Series doesn't look nice
# Out:
#                              Test 1
# Major         Gender
# Chemistry     Female      17.602500
#               Male        21.121500
#               Non-binary        NaN
# Comp. Biology Female      16.530000
#               Male              NaN
#               Non-binary        NaN
# Life Sciences Female      19.285875
#               Male        20.357250
#               Non-binary  16.836000
# Physics       Female      20.817000
#               Male        16.871000
#               Non-binary  20.205000

# %%
df_class.groupby(by=['Major', 'Gender']).agg([np.mean, np.std]).round(2)
# Out:
#                          Test 1       Test 2        Total
#                            mean   std   mean   std   mean   std
# Major         Gender
# Chemistry     Female      17.60  4.07  16.36  1.14  34.13  4.33
#               Male        21.12  3.90  17.22  0.60  38.35  4.50
#               Non-binary    NaN   NaN    NaN   NaN    NaN   NaN
# Comp. Biology Female      16.53   NaN  10.28   NaN  26.81   NaN
#               Male          NaN   NaN    NaN   NaN    NaN   NaN
#               Non-binary    NaN   NaN    NaN   NaN    NaN   NaN
# Life Sciences Female      19.29  2.07  14.80  2.61  34.09  3.84
#               Male        20.36  4.37  15.64  1.49  36.00  4.95
#               Non-binary  16.84  2.16  12.34  1.90  29.18  0.27
# Physics       Female      20.82   NaN  14.68   NaN  35.50   NaN
#               Male        16.87  4.35  16.50  1.89  34.17  5.15
#               Non-binary  20.20  0.87  15.30  0.88  35.50  1.74

# %%
mask = df_class['Gender'] == 'Female'
df_class[mask].groupby(by=['Major']).mean()
# Out:
#                   Test 1   Test 2      Total
# Major
# Chemistry      17.602500  16.3648  34.128500
# Comp. Biology  16.530000  10.2800  26.810000
# Life Sciences  19.285875  14.8010  34.086875
# Physics        20.817000  14.6800  35.497000

# %% [markdown]
# ## Exercise 1 :  Another dummy class

# %%
df_another = pd.read_excel("another-dummy-class.xlsx")
df_another = df_another.drop(columns = 'Unnamed: 0')
df_another.loc[df_another.Gender == 'Female'].Name
# Out:
# 1          Gustavo Vang
# 3         Owen Anderson
# 7     Maryjane Sandoval
# 8         Carl Trujillo
# 9           Halle Fritz
# 10        Marie Hoffman
# 13        Zoey Oconnell
# 14         Quentin Kemp
# 15             Leo Mayo
# 16      Camden Williams
# 17       Sidney Wiggins
# 18     Solomon Fletcher
# 19    Riley Christensen
# 22        Braydon Duran
# 23         Jalen Harmon
# 24             Ean Haas
# 32          Katie Ayers
# Name: Name, dtype: object

# %%
pd.Series.to_frame(df_another.groupby(by=['Major', 'Gender']).size())
# Out:
#                       0
# Major        Gender
# Chemistry    Female   5
#              Male     3
# Comp. Bio    Female   1
# Life Science Female   9
#              Male     5
# Physics      Female   2
#              Male    10

# %%
# can also use this from earlier
major_count = dict(df_another.groupby(by=['Major']).size())
major_count = dict(sorted(major_count.items(), key=lambda item: item[1],reverse=True))
import matplotlib.pyplot as plt
plt.bar(major_count.keys(), major_count.values())
plt.title('Number of students in each major')
# Out:
# Text(0.5, 1.0, 'Number of students in each major')
